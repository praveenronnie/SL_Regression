# %%
import joblib

loaded_data = joblib.load(open("trained_set.pkl", 'rb'))

# %%
import pandas as pd
# DataFrame is used because of training data with dataframe from the excelsheet. eg..YearsExperience, Salary
result = loaded_data.predict(new_pred)
new_pred = pd.DataFrame([[10]] , columns = ["YearsExperience"])

# %%
result
# Out:
# array([119905.85041792])
