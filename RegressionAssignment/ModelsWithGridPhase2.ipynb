# %%
import pandas as pd
import joblib
from sklearn.model_selection import GridSearchCV

model = joblib.load("regression_best_model.pkl")

new_data = pd.DataFrame({
    'age': [25],
    'bmi': [24],
    'children': [0],
    'sex_male': [1],
    'smoker_yes': [0],
})
model.predict(new_data)
# Out:
# array([3780.9614], dtype=float32)
